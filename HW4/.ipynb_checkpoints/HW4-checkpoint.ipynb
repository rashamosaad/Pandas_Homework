# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("whale_returns.csv")
# YOUR CODE HERE
whale_returns_df = pd.read_csv(whale_returns_csv, parse_dates=True, infer_datetime_format=True)
whale_returns_df = whale_returns_df.set_index('Date')
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
# YOUR CODE HERE
whale_returns_df.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
whale_returns_df.dropna(inplace=True)
whale_returns_df.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("algo_returns.csv")
# YOUR CODE HERE
algo_returns_df = pd.read_csv(algo_returns_csv, parse_dates=True, infer_datetime_format=True)
algo_returns_df = algo_returns_df.set_index('Date')
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
# YOUR CODE HERE
algo_returns_df.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
algo_returns_df.dropna(inplace=True)
algo_returns_df.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("sp500_history.csv")
# YOUR CODE HERE
sp500_df = pd.read_csv(sp500_history_csv, parse_dates=True, infer_datetime_format=True )
sp500_df = sp500_df.set_index('Date')
sp500_df.head()
# Out:
#               Close
# Date
# 23-Apr-19  $2933.68
# 22-Apr-19  $2907.97
# 18-Apr-19  $2905.03
# 17-Apr-19  $2900.45
# 16-Apr-19  $2907.06

# %%
# Check Data Types
# YOUR CODE HERE
sp500_df['Close'].dtypes
# Out:
# dtype('O')

# %%
# Fix Data Types
# YOUR CODE HERE
sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")
sp500_df.head()
# Out:
#              Close
# Date
# 23-Apr-19  2933.68
# 22-Apr-19  2907.97
# 18-Apr-19  2905.03
# 17-Apr-19  2900.45
# 16-Apr-19  2907.06

# %%
#change date format
sp500_df.index = pd.to_datetime(sp500_df.index).to_series().dt.strftime('%Y-%m-%d')
sp500_df.dropna(inplace=True)
sp500_df.isna().sum()
sp500_df.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
sp500_df["Close"] = sp500_df["Close"].astype(float)
sp500_df["Close"].dtypes
# Out:
# dtype('float64')

# %%
# Calculate Daily Returns
# YOUR CODE HERE
sp500_returns_df = sp500_df.pct_change()
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
# YOUR CODE HERE
sp500_returns_df.dropna()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename Column
# YOUR CODE HERE
sp500_returns_df.rename(columns = {'Close': 'SP500'}, inplace = True)
# sp500_returns_df.index = pd.to_datetime(sp500_returns_df.index).strftime('%Y-%m-%d')

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
combined_returns_df = pd.concat([whale_returns_df, algo_returns_df, sp500_returns_df], axis="columns", join="inner")
combined_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
# YOUR CODE HERE
combined_returns_df.plot(figsize=(20,10))
# Yes. Berkshire Hathaway, Algo2 and Soros Fund seem to have outperformed S&P500 in many instances.

# %%
# Plot cumulative returns
# YOUR CODE HERE
cumulative_portfolio_returns = (1+ combined_returns_df).cumprod()
cumulative_portfolio_returns.plot(figsize=(20,10))

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE
combined_returns_df.plot(kind='box', figsize=(20,10))
#Berkshire, Tiger and Algo 1 are the riskiest

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio.
combined_returns_std = combined_returns_df.std()
combined_returns_std.sort_values()
# Out:
# PAULSON & CO.INC.              0.007023
# Algo 1                         0.007620
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 2                         0.008342
# SP500                          0.008587
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
volatility = combined_returns_df.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
print(volatility)
# Based on annulaized SD data, Berkshire Hathaway and Tiger Global Managament are riskier than SP500
# Out:
# PAULSON & CO.INC.              0.111488
# Algo 1                         0.120967
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 2                         0.132430
# SP500                          0.136313
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
combined_returns_std_rolling = combined_returns_df.rolling(window=21).std()
combined_returns_std_rolling.plot(figsize=(20,10), title='Rolling SD for S&P500, Whale & Algo portfolios over 21  days')

# %%
# Construct a correlation table
# YOUR CODE HERE
correlation = combined_returns_df.corr()
correlation
#heatmap
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500                                         0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
#Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. 
#Does the portfolio seem sensitive to movements in the S&P 500?
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE
berkshire_hathaway_covariance = combined_returns_df['BERKSHIRE HATHAWAY INC'].cov(combined_returns_df['SP500'])
berkshire_hathaway_covariance
variance = combined_returns_df['SP500'].var()
variance
berkshire_beta = berkshire_hathaway_covariance/variance
berkshire_beta
# Out:
# -0.020846489408902668

# %%
rolling_covariance = combined_returns_df['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_returns_df['SP500'])
rolling_variance = combined_returns_df['SP500'].rolling(window=60).var()
rolling_beta = rolling_covariance/rolling_variance
rolling_beta.plot(figsize=(20,10))

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
combined_returns_df.ewm(halflife=60).std().plot(figsize=(20,10), title = "Exponentially Weighted Average")
# An exponential moving average (EMA) is an average price calculation over a specific time period that puts
# more weight on the most recent price data causing it to react faster to price change.

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE
sharpe_ratios = (combined_returns_df.mean() * 252) / (combined_returns_df.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe_ratios.plot(kind="bar")

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# From the bar graph it looks like the Sharpe Ratios for Algo 1 and Algo 2 are higher than those of SP500 and the Whale Portfolios.
# However, we can not conclude that the algorithmic strategies are the reason since Berkshire Hathaway is also doing well without
# using algorithmic strategies.

# %% [markdown]
# # Portfolio Returns
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.

# %%
#Calculate the returns for each stock.
csvpath = Path("AMT.csv")
AMT_df = pd.read_csv(csvpath, index_col="Date", infer_datetime_format=True, parse_dates=True)
AMT_df.sort_index(inplace=True)
AMT_returns_df = AMT_df.pct_change()
AMT_returns_df.dropna(inplace=True)
AMT_returns_df.head()
# Out:
#                         Close
# Date
# 2015-01-05 16:00:00 -0.014448
# 2015-01-06 16:00:00 -0.002647
# 2015-01-07 16:00:00  0.010513
# 2015-01-08 16:00:00  0.009293
# 2015-01-09 16:00:00 -0.005104

# %%
#Calculate the returns for each stock.
csvpath = Path("ANET.csv")
ANET_df = pd.read_csv(csvpath, index_col="Date", infer_datetime_format=True, parse_dates=True)
ANET_df.sort_index(inplace=True)
ANET_returns_df = ANET_df.pct_change()
ANET_returns_df.dropna(inplace=True)
ANET_returns_df.head()
# Out:
#                         Close
# Date
# 2015-01-05 16:00:00  0.017869
# 2015-01-06 16:00:00  0.000157
# 2015-01-07 16:00:00  0.020843
# 2015-01-08 16:00:00  0.015045
# 2015-01-09 16:00:00  0.004537

# %%
#Calculate the returns for each stock.
csvpath = Path("CZZ.csv")
CZZ_df = pd.read_csv(csvpath, index_col="Date", infer_datetime_format=True, parse_dates=True)
CZZ_df.sort_index(inplace=True)
CZZ_returns_df = CZZ_df.pct_change()
CZZ_returns_df.dropna(inplace=True)
CZZ_returns_df.head()
# Out:
#                         Close
# Date
# 2015-01-05 16:00:00 -0.065977
# 2015-01-06 16:00:00 -0.033241
# 2015-01-07 16:00:00  0.000000
# 2015-01-08 16:00:00  0.025788
# 2015-01-09 16:00:00 -0.015363

# %%
my_portfolio_returns_df = pd.concat([AMT_returns_df, ANET_returns_df, CZZ_returns_df], axis="columns", join="inner")
my_portfolio_returns_df.columns = ["AMT", "ANET", "CZZ"]
my_portfolio_returns_df.head()
# Out:
#                           AMT      ANET       CZZ
# Date
# 2015-01-05 16:00:00 -0.014448  0.017869 -0.065977
# 2015-01-06 16:00:00 -0.002647  0.000157 -0.033241
# 2015-01-07 16:00:00  0.010513  0.020843  0.000000
# 2015-01-08 16:00:00  0.009293  0.015045  0.025788
# 2015-01-09 16:00:00 -0.005104  0.004537 -0.015363

# %% [markdown]
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.

# %%
# Using those returns, calculate the weighted returns for your entire portfolio assuming 
# an equal number of shares for each stock.
weights = [1/3, 1/3, 1/3]
new_portfolio_returns_df = my_portfolio_returns_df.dot(weights)
new_portfolio_returns_df.index = pd.to_datetime(new_portfolio_returns_df.index).to_series().dt.strftime('%Y-%m-%d')
new_portfolio_returns_df.head()
# Out:
# Date
# 2015-01-05   -0.020852
# 2015-01-06   -0.011910
# 2015-01-07    0.010452
# 2015-01-08    0.016708
# 2015-01-09   -0.005310
# dtype: float64

# %%
#Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
aggregate_returns_df = pd.concat([combined_returns_df, new_portfolio_returns_df], axis="columns", join="inner")
aggregate_returns_df.columns = ["SOROS FUND MANAGEMENT LLC", "PAULSON & CO.INC.", "TIGER GLOBAL MANAGEMENT LLC", 
                                 "BERKSHIRE HATHAWAY INC", "Algo 1", "Algo 2", "SP500", "Rasha"]
aggregate_returns_df.dropna(inplace=True)
aggregate_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2015-03-03                  -0.001266          -0.004981
# 2015-03-04                   0.002230           0.003241
# 2015-03-05                   0.004016           0.004076
# 2015-03-06                  -0.007905          -0.003574
# 2015-03-09                   0.000582           0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500     Rasha
# Date
# 2015-03-03 -0.000949  0.004408 -0.009932
# 2015-03-04  0.002416 -0.001195 -0.015022
# ...

# %%
#The annualized standard deviation (252 trading days) for all portfolios.
aggregate_retruns_std_df = aggregate_returns_df.std() * np.sqrt(252)
aggregate_retruns_std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# Rasha                          0.242112
# dtype: float64

# %%
#The plotted rolling standard deviation using a 60 trading day window for all portfolios.
aggregate_retruns_std_df.rolling(window=60) 
aggregate_retruns_std_df.plot(figsize=(20,10))

# %%
#The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
aggregate_sharpe_ratios = (aggregate_returns_df.mean() * 252) / (aggregate_returns_df.std() * np.sqrt(252))
aggregate_sharpe_ratios.sort_values()
# Out:
# SP500                         -0.518582
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# SOROS FUND MANAGEMENT LLC      0.342894
# Algo 2                         0.484334
# BERKSHIRE HATHAWAY INC         0.606743
# Rasha                          1.186332
# Algo 1                         1.369589
# dtype: float64

# %%
aggregate_sharpe_ratios.plot(kind="bar", figsize=(20,10))

# %%
#A correlation table
my_portfolio_returns_df.corr()
# Out:
#            AMT      ANET       CZZ
# AMT   1.000000  0.275998  0.351377
# ANET  0.275998  1.000000  0.218076
# CZZ   0.351377  0.218076  1.000000

# %%
#Using your custom portfolio and one other of your choosing:
covariance = algo_returns_df['Algo 1'].cov(aggregate_returns_df['Rasha'])
variance = algo_returns_df["Algo 1"].var()
rasha_beta = covariance/variance
rasha_beta
                                   
#The plotted beta.
rolling_covariance = algo_returns_df['Algo 1'].rolling(window=60).cov(aggregate_returns_df['Rasha'])
rolling_variance = variance = algo_returns_df["Algo 1"].rolling(window=60).var()
rasha_rolling_beta = rolling_covariance/rolling_variance
rasha_rolling_beta.plot(figsize=(20,10), title="my portfolio's beta compared to Algo 1's portfolio")

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
my_portfolio_prices_df = pd.concat([AMT_df, ANET_df, CZZ_df], axis="columns", join="inner")
my_portfolio_prices_df.columns = ["AMT", "ANET", "CZZ"]
my_portfolio_prices_df.head()
my_portfolio_prices_df['AMT'].head()
# Out:
# Date
# 2015-01-02 16:00:00    99.67
# 2015-01-05 16:00:00    98.23
# 2015-01-06 16:00:00    97.97
# 2015-01-07 16:00:00    99.00
# 2015-01-08 16:00:00    99.92
# Name: AMT, dtype: float64

# %%
# Read the second stock
# YOUR CODE HERE
my_portfolio_prices_df['ANET'].head()
# Out:
# Date
# 2015-01-02 16:00:00    62.68
# 2015-01-05 16:00:00    63.80
# 2015-01-06 16:00:00    63.81
# 2015-01-07 16:00:00    65.14
# 2015-01-08 16:00:00    66.12
# Name: ANET, dtype: float64

# %%
# Read the third stock
# YOUR CODE HERE
my_portfolio_prices_df['CZZ'].head()
# Out:
# Date
# 2015-01-02 16:00:00    7.73
# 2015-01-05 16:00:00    7.22
# 2015-01-06 16:00:00    6.98
# 2015-01-07 16:00:00    6.98
# 2015-01-08 16:00:00    7.16
# Name: CZZ, dtype: float64

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
custom_stocks_combined_df = pd.concat([AMT_df, ANET_df, CZZ_df], axis="columns", join="inner")
custom_stocks_combined_df.head()
custom_stocks_combined_df.index = pd.to_datetime(custom_stocks_combined_df.index).to_series().dt.strftime('%Y-%m-%d')

# %%
# Reset the index
# YOUR CODE HERE
custom_stocks_combined_df.index = pd.to_datetime(custom_stocks_combined_df.index).to_series().dt.strftime('%Y-%m-%d')
custom_stocks_combined_df.head()
# Out:
#             Close  Close  Close
# Date
# 2015-01-02  99.67  62.68   7.73
# 2015-01-05  98.23  63.80   7.22
# 2015-01-06  97.97  63.81   6.98
# 2015-01-07  99.00  65.14   6.98
# 2015-01-08  99.92  66.12   7.16

# %%
# Pivot so that each column of prices represents a unique symbol
# YOUR CODE HERE
custom_stocks_combined_df.columns = ["AMT", "ANET", "CZZ"]
custom_stocks_combined_df.head()
# Out:
#               AMT   ANET   CZZ
# Date
# 2015-01-02  99.67  62.68  7.73
# 2015-01-05  98.23  63.80  7.22
# 2015-01-06  97.97  63.81  6.98
# 2015-01-07  99.00  65.14  6.98
# 2015-01-08  99.92  66.12  7.16

# %%
# Drop Nulls
# YOUR CODE HERE
custom_stocks_combined_df.isna().sum()
custom_stocks_combined_df.dropna()
# Out:
#                AMT    ANET    CZZ
# Date
# 2015-01-02   99.67   62.68   7.73
# 2015-01-05   98.23   63.80   7.22
# 2015-01-06   97.97   63.81   6.98
# 2015-01-07   99.00   65.14   6.98
# 2015-01-08   99.92   66.12   7.16
# ...            ...     ...    ...
# 2020-09-24  236.18  198.46  15.52
# 2020-09-25  239.81  200.64  15.14
# 2020-09-28  240.00  205.05  14.77
# 2020-09-29  240.12  210.46  14.28
# 2020-09-30  241.73  206.93  14.85
#
# [1447 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
custom_stocks_returns_combined_df= custom_stocks_combined_df.pct_change()
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
rasha_portfolio_df = custom_stocks_returns_combined_df.dot(weights)
rasha_portfolio_df.dropna()
myportfolio_std = rasha_portfolio_df.std()
myportfolio_annualized_std = rasha_portfolio_df_annualized = rasha_portfolio_df.std() * np.sqrt(252)
print(rasha_portfolio_df.head())
round(myportfolio_std, 2)
round(myportfolio_annualized_std,2 )
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.020852
# 2015-01-06   -0.011910
# 2015-01-07    0.010452
# 2015-01-08    0.016708
# dtype: float64
# 0.29

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE
custom_combined_portfolio_df = pd.concat([combined_returns_df, rasha_portfolio_df], axis="columns", join="inner")

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YpOUR CODE HERE
custom_combined_portfolio_df.columns = ["SOROS FUND MANAGEMENT LLC", "PAULSON & CO.INC.", "TIGER GLOBAL MANAGEMENT LLC", 
                                 "BERKSHIRE HATHAWAY INC", "Algo 1", "Algo 2", "SP500", "Rasha"]

# %%
custom_combined_portfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2015-03-03                  -0.001266          -0.004981
# 2015-03-04                   0.002230           0.003241
# 2015-03-05                   0.004016           0.004076
# 2015-03-06                  -0.007905          -0.003574
# 2015-03-09                   0.000582           0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500     Rasha
# Date
# 2015-03-03 -0.000949  0.004408 -0.009932
# 2015-03-04  0.002416 -0.001195 -0.015022
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk 
# YOUR CODE HERE
Volatility = custom_combined_portfolio_df.std().plot(figsize=(20,10), title="Volatility of Aggregate Combined Portfolio")

# %%
# Annulaized Volatilty
annualized_volatility = custom_combined_portfolio_df.std() * np.sqrt(252)
annualized_volatility.plot(figsize=(20,10))

# %%
# Rolling (STD)
# YOUR CODE HERE
rolling_volatility = custom_combined_portfolio_df.rolling(window=60).std().plot(figsize=(20,10))

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
sharpe_ratios = (custom_combined_portfolio_df.mean() * 252) / (custom_combined_portfolio_df.std() * np.sqrt(252))
sharpe_ratios.sort_values()
# Out:
# SP500                         -0.518582
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# SOROS FUND MANAGEMENT LLC      0.356417
# Algo 2                         0.501364
# BERKSHIRE HATHAWAY INC         0.621810
# Rasha                          1.180065
# Algo 1                         1.378648
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe_ratios.plot(kind="bar", figsize=(20,10), title = 'Sharpe Ratios for All Portfolio inlcuding My Portfolio')

# %%
# Create a correlation analysis
# YOUR CODE HERE
correlation_df = custom_combined_portfolio_df.corr()
correlation_df.head()
corr_sum_df = correlation_df.sum().sort_values()
corr_sum_df
# Out:
# SP500                          0.924169
# Algo 1                         2.541669
# TIGER GLOBAL MANAGEMENT LLC    3.483948
# Rasha                          3.787884
# PAULSON & CO.INC.              4.069771
# BERKSHIRE HATHAWAY INC         4.227918
# Algo 2                         4.610116
# SOROS FUND MANAGEMENT LLC      4.766063
# dtype: float64

# %%
sns.heatmap(correlation_df, vmin=-1, vmax=1)

# %%
# So despite that Rasha's portfolio has high annualizd STD of 0.29, it hasthe second highest Sharpe ratio of 1.18 
# after the Sharpe ratio of Algo 1 which is 1.38. So for the return on every unit of risk (the risk reward ratio), 1.18 is 
# a good ratio when compared to the other portfolios.
